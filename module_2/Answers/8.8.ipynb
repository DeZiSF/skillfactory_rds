# %%
import pandas as pd

# %%
data = pd.read_excel('nakladnaya.xls')
data = data.drop_duplicates()
display(data)
# Out:
#     Unnamed: 0                         Unnamed: 1  \
# 0          NaN                                NaN
# 1          NaN                                NaN
# 2          NaN                  Грузоотправитель:
# 4          NaN                   Грузополучатель:
# 6          NaN  Основание для отпуска: Договор №
# 9          NaN                                  №
# 10         NaN                                п/п
# 11         NaN                                  1
# 12         NaN                                  2
# 14         NaN                                NaN
# 16         NaN                                NaN
# 18         NaN                                NaN
# 20         NaN                                NaN
# 22         NaN                                NaN
# 23         NaN                                NaN
#
#                                      Unnamed: 2  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 4                                           NaN
# 6                                           NaN
# 9   Наименование товарно-материальных ценностей
# 10                                          NaN
# 11                        Велосипед "Спринтер"
# 12                          Велосипед "Малютка"
# 14                              Всего отпущено
# 16                                   На сумму
# 18                            Отпуск разрешил
# 20                                         М.П.
# 22                                   Отпустил
# 23                                    Получил
#
#                            Unnamed: 3                         Unnamed: 4  \
# 0                           НАКЛАДНАЯ  № 5764809  от "08" апреля 2018 г.
# 1                                 NaN                                NaN
# 2              ООО "Первый строитель"                                NaN
# 4                 ООО "Стройка века"                                 NaN
# 6                                 NaN                                 86
# 9                                 NaN                                NaN
# 10                                NaN                                NaN
# 11                                NaN                                NaN
# 12                                NaN                                NaN
# 14               2 (два) наименования                                NaN
# 16  80 000 (восемьдесят тысяч) рублей                                NaN
# 18                     Зам. Директора                                NaN
# 20                                NaN                                NaN
# 22                         Кладовщик                                 NaN
# 23                          Водитель                                 NaN
#
#                Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# 0                     NaN        NaN         NaN        NaN         NaN
# 1                     NaN        NaN         NaN        NaN         NaN
# 2                     NaN        NaN         NaN        NaN         NaN
# 4                     NaN        NaN         NaN        NaN         NaN
# 6   от "02"апреля 2018 г.        NaN         NaN        NaN         NaN
# 9                     NaN   Ед. изм.         NaN        NaN  Количество
# 10                    NaN        NaN         NaN        NaN         NaN
# 11                    NaN         шт         NaN        NaN           5
# 12                    NaN         шт         NaN        NaN          10
# 14                    NaN        NaN         NaN        NaN         NaN
# 16                    NaN        NaN         NaN        NaN         NaN
# 18                    NaN        NaN         NaN    Куликов         NaN
# 20                    NaN        NaN         NaN        NaN         NaN
# 22                    NaN        NaN         NaN      Мазов         NaN
# 23                    NaN        NaN         NaN  Дроценко          NaN
#
#     Unnamed: 10     Unnamed: 11 Unnamed: 12
# 0           NaN             NaN         NaN
# 1           NaN             NaN         NaN
# 2           NaN             NaN         NaN
# 4           NaN             NaN         NaN
# 6           NaN             NaN         NaN
# 9           NaN          Цена,      Сумма,
# 10          NaN       руб. коп.   руб. коп.
# 11          NaN            9000       45000
# 12          NaN            3500       35000
# 14          NaN             NaN         NaN
# 16          NaN             NaN         NaN
# 18          NaN   Куликов П.Д.          NaN
# 20          NaN             NaN         NaN
# 22          NaN      Мазов Р.К.         NaN
# 23          NaN  Дроценко А.С.          NaN

# %%
data.iloc[0, 4][2:9]
# Out:
# '5764809'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 23
# Data columns (total 13 columns):
# Unnamed: 0     0 non-null float64
# Unnamed: 1     7 non-null object
# Unnamed: 2     9 non-null object
# Unnamed: 3     8 non-null object
# Unnamed: 4     2 non-null object
# Unnamed: 5     1 non-null object
# Unnamed: 6     3 non-null object
# Unnamed: 7     0 non-null float64
# Unnamed: 8     3 non-null object
# Unnamed: 9     3 non-null object
# Unnamed: 10    0 non-null float64
# Unnamed: 11    7 non-null object
# Unnamed: 12    4 non-null object
# dtypes: float64(3), object(10)
# memory usage: 2.3+ KB

# %%
data.iloc[6:8, [1, 2, 6, 9, 11, 12]]
# Out:
#    Unnamed: 1             Unnamed: 2 Unnamed: 6 Unnamed: 9 Unnamed: 11  \
# 10        п/п                    NaN        NaN        NaN   руб. коп.
# 11          1  Велосипед "Спринтер"          шт          5        9000
#
#    Unnamed: 12
# 10   руб. коп.
# 11       45000

# %%
data.iloc[6:8, [0, 2, 6, 9, 11, 12]]
# Out:
#     Unnamed: 0             Unnamed: 2 Unnamed: 6 Unnamed: 9 Unnamed: 11  \
# 10         NaN                    NaN        NaN        NaN   руб. коп.
# 11         NaN  Велосипед "Спринтер"          шт          5        9000
#
#    Unnamed: 12
# 10   руб. коп.
# 11       45000

# %%
data.iloc[7:8, :].dropna(axis=1, how='all')
# Out:
#    Unnamed: 1             Unnamed: 2 Unnamed: 6 Unnamed: 9 Unnamed: 11  \
# 11          1  Велосипед "Спринтер"          шт          5        9000
#
#    Unnamed: 12
# 11       45000

# %%
data.iloc[6:8, :].dropna(axis=1, how='any')
# Out:
#    Unnamed: 1 Unnamed: 11 Unnamed: 12
# 10        п/п   руб. коп.   руб. коп.
# 11          1        9000       45000

# %%
data.iloc[6:8, :].dropna(axis=1, how='all')
# Out:
#    Unnamed: 1             Unnamed: 2 Unnamed: 6 Unnamed: 9 Unnamed: 11  \
# 10        п/п                    NaN        NaN        NaN   руб. коп.
# 11          1  Велосипед "Спринтер"          шт          5        9000
#
#    Unnamed: 12
# 10   руб. коп.
# 11       45000

# %%
<menu>    
    <dish name="Кура">  
        <price>40</price>  
        <weight>300</weight>  
        <class>Мясо</class>  
    </dish>
    <dish name="Греча">  
        <price>20</price>  
        <weight>200</weight>  
        <class>Крупа</class>  
    </dish>
</menu>
